# %% [markdown]
# ### Work with Virginia Criminal Expungement Data
# ######Source: https://virginiacourtdata.org/
# Goal: upload the data, save as a delta table, and perform various analyses with Spark

# %%
from delta import *
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("MyApp") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .getOrCreate()

spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="/?o=52368859589716#setting/sparkui/0128-165643-erqkptyh/driver-6719764943701249625">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# File location and type
file_location = "/FileStore/tables/circuit_criminal_2000_anon_00.csv"
file_type = "csv"

# CSV options
infer_schema = "false"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

# %%
if DeltaTable.isDeltaTable(spark, '/tmp/delta-table-1'):
  print('Table exists. Removing old table...')
  dbutils.fs.rm('/tmp/delta-table-1',recurse=True) # remove if it already exists
df.write.format("delta").save('/tmp/delta-table-1')
# Out:
# Table exists. Removing old table...

# %%
df = spark.read.format("delta").load("/tmp/delta-table-1")
df.show(vertical=True)
# Out:
# -RECORD 0---------------------------------------------
#  HearingDate                   | 2000-12-19
#  HearingResult                 | Dismissed
#  HearingJury                   | null
#  HearingPlea                   | null
#  HearingType                   | Under Advisement
#  HearingRoom                   | null
#  fips                          | 91
#  Filed                         | 2000-02-16
#  Commencedby                   | General District ...
#  Locality                      | COMMONWEALTH OF VA
#  Sex                           | Male
#  Race                          | White Caucasian (...
#  Address                       | BLUE GRASS, VA  2...
#  Charge                        | ELUDE LAW ENFORCE...
#  CodeSection                   | 46.2-817
#  ChargeType                    | Misdemeanor
#  Class                         | null
#  OffenseDate                   | 1999-11-19
#  ArrestDate                    | null
#  DispositionCode               | Dismissed
#  DispositionDate               | 2000-12-19
#  ConcludedBy                   | Dismissal
#  AmendedCharge                 | null
#  AmendedCodeSection            | null
#  AmendedChargeType             | null
#  JailPenitentiary              | null
#  ConcurrentConsecutive         | null
#  LifeDeath                     | null
#  SentenceTime                  | null
#  SentenceSuspended             | null
#  OperatorLicenseSuspensionTime | null
#  FineAmount                    | null
#  Costs                         | null
#  FinesCostPaid                 | null
#  ProgramType                   | null
#  ProbationType                 | null
#  ProbationTime                 | null
#  ProbationStarts               | null
#  CourtDMVSurrender             | null
#  DriverImprovementClinic       | null
#  DrivingRestrictions           | null
#  RestrictionEffectiveDate      | null
#  RestrictionEndDate            | null
#  VAAlcoholSafetyAction         | null
#  RestitutionPaid               | null
#  RestitutionAmount             | null
#  Military                      | null
#  TrafficFatality               | null
#  AppealedDate                  | null
#  person_id                     | 227220000000460
# -RECORD 1---------------------------------------------
#  HearingDate                   | 2000-09-19
#  HearingResult                 | Dismissed
#  HearingJury                   | null
#  HearingPlea                   | null
#  HearingType                   | Trial
#  HearingRoom                   | null
#  fips                          | 91
#  Filed                         | 2000-05-19
#  Commencedby                   | J&Dr Appeal
#  Locality                      | COMMONWEALTH OF VA
#  Sex                           | Male
#  Race                          | White Caucasian (...
#  Address                       | STAUNTON, VA  24401
#  Charge                        | OBSCENE PHONE CALL
#  CodeSection                   | 18.2-427
#  ChargeType                    | Misdemeanor
#  Class                         | 1
#  OffenseDate                   | 2000-03-10
#  ArrestDate                    | null
#  DispositionCode               | Not Guilty/Acquitted
#  DispositionDate               | 2000-09-19
#  ConcludedBy                   | Dismissal
#  AmendedCharge                 | null
#  AmendedCodeSection            | null
#  AmendedChargeType             | null
#  JailPenitentiary              | null
#  ConcurrentConsecutive         | null
#  LifeDeath                     | null
#  SentenceTime                  | null
#  SentenceSuspended             | null
#  OperatorLicenseSuspensionTime | null
#  FineAmount                    | null
#  Costs                         | null
#  FinesCostPaid                 | null
#  ProgramType                   | null
#  ProbationType                 | null
#  ProbationTime                 | null
#  ProbationStarts               | null
#  CourtDMVSurrender             | null
#  DriverImprovementClinic       | null
#  DrivingRestrictions           | null
#  RestrictionEffectiveDate      | null
#  RestrictionEndDate            | null
#  VAAlcoholSafetyAction         | null
#  RestitutionPaid               | null
#  RestitutionAmount             | null
#  Military                      | null
#  TrafficFatality               | null
#  AppealedDate                  | null
#  person_id                     | 352110000000068
# -RECORD 2---------------------------------------------
#  HearingDate                   | 2000-09-07
#  HearingResult                 | Sent
#  HearingJury                   | null
#  HearingPlea                   | null
#  HearingType                   | Trial
#  HearingRoom                   | null
#  fips                          | 91
#  Filed                         | 2000-02-16
#  Commencedby                   | General District ...
#  Locality                      | COMMONWEALTH OF VA
#  Sex                           | Male
#  Race                          | White Caucasian (...
#  Address                       | BLUE GRASS, VA  2...
#  Charge                        | SHOOT FROM A ROAD
#  CodeSection                   | 18.2-286
#  ChargeType                    | Misdemeanor
#  Class                         | null
#  OffenseDate                   | 1999-11-19
#  ArrestDate                    | null
#  DispositionCode               | Guilty
#  DispositionDate               | 2000-09-07
#  ConcludedBy                   | Guilty Plea
#  AmendedCharge                 | null
#  AmendedCodeSection            | null
#  AmendedChargeType             | null
#  JailPenitentiary              | null
#  ConcurrentConsecutive         | null
#  LifeDeath                     | null
#  SentenceTime                  | null
#  SentenceSuspended             | null
#  OperatorLicenseSuspensionTime | null
#  FineAmount                    | 300
#  Costs                         | 81
#  FinesCostPaid                 | t
#  ProgramType                   | null
#  ProbationType                 | null
#  ProbationTime                 | null
#  ProbationStarts               | null
#  CourtDMVSurrender             | null
#  DriverImprovementClinic       | null
#  DrivingRestrictions           | null
#  RestrictionEffectiveDate      | null
#  RestrictionEndDate            | null
#  VAAlcoholSafetyAction         | null
#  RestitutionPaid               | null
#  RestitutionAmount             | null
#  Military                      | null
#  TrafficFatality               | null
#  AppealedDate                  | null
#  person_id                     | 216180000001247
# -RECORD 3---------------------------------------------
#  HearingDate                   | 2000-09-07
#  HearingResult                 | Nolle Prosequi
#  HearingJury                   | null
#  HearingPlea                   | null
#  HearingType                   | Trial
#  HearingRoom                   | null
#  fips                          | 91
#  Filed                         | 2000-02-16
#  Commencedby                   | General District ...
#  Locality                      | COMMONWEALTH OF VA
#  Sex                           | Male
#  Race                          | White Caucasian (...
#  Address                       | BLUE GRASS, VA  2...
#  Charge                        | SHOOT FROM A VEHICLE
#  CodeSection                   | 29.1-521(6)
#  ChargeType                    | Misdemeanor
#  Class                         | null
#  OffenseDate                   | 1999-11-19
#  ArrestDate                    | null
#  DispositionCode               | Nolle Prosequi
#  DispositionDate               | 2000-09-07
#  ConcludedBy                   | Nolle Prosequi
#  AmendedCharge                 | null
#  AmendedCodeSection            | null
#  AmendedChargeType             | null
#  JailPenitentiary              | null
#  ConcurrentConsecutive         | null
#  LifeDeath                     | null
#  SentenceTime                  | null
#  SentenceSuspended             | null
#  OperatorLicenseSuspensionTime | null
#  FineAmount                    | null
#  Costs                         | null
#  FinesCostPaid                 | null
#  ProgramType                   | null
#  ProbationType                 | null
#  ProbationTime                 | null
#  ProbationStarts               | null
#  CourtDMVSurrender             | null
#  DriverImprovementClinic       | null
#  DrivingRestrictions           | null
#  RestrictionEffectiveDate      | null
#  RestrictionEndDate            | null
#  VAAlcoholSafetyAction         | null
#  RestitutionPaid               | null
#  RestitutionAmount             | null
#  Military                      | null
#  TrafficFatality               | null
#  AppealedDate                  | null
#  person_id                     | 216180000001247
# -RECORD 4---------------------------------------------
#  HearingDate                   | 2000-09-07
#  HearingResult                 | Sent
#  HearingJury                   | null
#  HearingPlea                   | null
#  HearingType                   | Trial
#  HearingRoom                   | null
#  fips                          | 91
#  Filed                         | 2000-02-16
#  Commencedby                   | General District ...
#  Locality                      | COMMONWEALTH OF VA
#  Sex                           | Male
#  Race                          | White Caucasian (...
#  Address                       | BLUE GRASS, VA  2...
#  Charge                        | HUNT POSTED W/O W...
#  CodeSection                   | 18.2-134
#  ChargeType                    | Misdemeanor
#  Class                         | null
#  OffenseDate                   | 1999-11-19
#  ArrestDate                    | null
#  DispositionCode               | Guilty
#  DispositionDate               | 2000-09-07
#  ConcludedBy                   | Guilty Plea
#  AmendedCharge                 | null
#  AmendedCodeSection            | null
#  AmendedChargeType             | null
#  JailPenitentiary              | null
#  ConcurrentConsecutive         | null
#  LifeDeath                     | null
#  SentenceTime                  | null
#  SentenceSuspended             | null
#  OperatorLicenseSuspensionTime | null
#  FineAmount                    | 50
#  Costs                         | 53
#  FinesCostPaid                 | t
#  ProgramType                   | null
#  ProbationType                 | null
#  ProbationTime                 | null
#  ProbationStarts               | null
#  CourtDMVSurrender             | null
#  DriverImprovementClinic       | null
#  DrivingRestrictions           | null
#  RestrictionEffectiveDate      | null
#  RestrictionEndDate            | null
#  VAAlcoholSafetyAction         | null
#  RestitutionPaid               | null
#  RestitutionAmount             | null
#  Military                      | null
#  TrafficFatality               | null
#  AppealedDate                  | null
#  person_id                     | 216180000001247
# -RECORD 5---------------------------------------------
#  HearingDate                   | 2000-09-07
#  HearingResult                 | Sent
#  HearingJury                   | null
#  HearingPlea                   | null
#  HearingType                   | Trial
#  HearingRoom                   | null
#  fips                          | 91
#  Filed                         | 2000-02-16
#  Commencedby                   | General District ...
#  Locality                      | COMMONWEALTH OF VA
#  Sex                           | Male
#  Race                          | White Caucasian (...
#  Address                       | BLUE GRASS, VA  2...
#  Charge                        | ATTEMPT TAKE DEER...
#  CodeSection                   | 29.1-523
#  ChargeType                    | Misdemeanor
#  Class                         | null
#  OffenseDate                   | 1999-11-19
#  ArrestDate                    | null
#  DispositionCode               | Guilty
#  DispositionDate               | 2000-09-07
#  ConcludedBy                   | Guilty Plea
#  AmendedCharge                 | null
#  AmendedCodeSection            | null
#  AmendedChargeType             | null
#  JailPenitentiary              | null
#  ConcurrentConsecutive         | null
#  LifeDeath                     | null
#  SentenceTime                  | null
#  SentenceSuspended             | null
#  OperatorLicenseSuspensionTime | null
#  FineAmount                    | 200
#  Costs                         | 33
#  FinesCostPaid                 | t
#  ProgramType                   | null
#  ProbationType                 | null
#  ProbationTime                 | null
#  ProbationStarts               | null
#  CourtDMVSurrender             | null
#  DriverImprovementClinic       | null
#  DrivingRestrictions           | null
#  RestrictionEffectiveDate      | null
#  RestrictionEndDate            | null
#  VAAlcoholSafetyAction         | null
#  RestitutionPaid               | null
#  RestitutionAmount             | null
#  Military                      | null
#  TrafficFatality               | null
#  AppealedDate                  | null
#  person_id                     | 216180000001247
# -RECORD 6---------------------------------------------
#  HearingDate                   | 2000-09-07
#  HearingResult                 | Sent
#  HearingJury                   | null
#  HearingPlea                   | null
#  HearingType                   | Trial
#  HearingRoom                   | null
#  fips                          | 91
#  Filed                         | 2000-02-16
#  Commencedby                   | General District ...
#  Locality                      | COMMONWEALTH OF VA
#  Sex                           | Male
#  Race                          | White Caucasian (...
#  Address                       | BLUE GRASS, VA  2...
#  Charge                        | ATTEMPT TAKE DEER...
#  CodeSection                   | 4VAC15-270-20
#  ChargeType                    | Misdemeanor
#  Class                         | null
#  OffenseDate                   | 1999-11-19
#  ArrestDate                    | null
#  DispositionCode               | Guilty
#  DispositionDate               | 2000-09-07
#  ConcludedBy                   | Guilty Plea
#  AmendedCharge                 | null
#  AmendedCodeSection            | null
#  AmendedChargeType             | null
#  JailPenitentiary              | null
#  ConcurrentConsecutive         | null
#  LifeDeath                     | null
#  SentenceTime                  | null
#  SentenceSuspended             | null
#  OperatorLicenseSuspensionTime | null
#  FineAmount                    | 50
#  Costs                         | 33
#  FinesCostPaid                 | t
#  ProgramType                   | null
#  ProbationType                 | null
#  ProbationTime                 | null
#  ProbationStarts               | null
#  CourtDMVSurrender             | null
#  DriverImprovementClinic       | null
#  DrivingRestrictions           | null
#  RestrictionEffectiveDate      | null
#  RestrictionEndDate            | null
#  VAAlcoholSafetyAction         | null
#  RestitutionPaid               | null
#  RestitutionAmount             | null
#  Military                      | null
#  TrafficFatality               | null
#  AppealedDate                  | null
#  person_id                     | 216180000001247
# -RECORD 7---------------------------------------------
#  HearingDate                   | 2000-09-07
#  HearingResult                 | Sent
#  HearingJury                   | null
#  HearingPlea                   | null
#  HearingType                   | Trial
#  HearingRoom                   | null
#  fips                          | 91
#  Filed                         | 2000-02-16
#  Commencedby                   | General District ...
#  Locality                      | COMMONWEALTH OF VA
#  Sex                           | Male
#  Race                          | White Caucasian (...
#  Address                       | BLUE GRASS, VA  2...
#  Charge                        | ASSIST TO SHOOT F...
#  CodeSection                   | 18.2-286
#  ChargeType                    | Misdemeanor
#  Class                         | null
#  OffenseDate                   | 1999-11-19
#  ArrestDate                    | null
#  DispositionCode               | Guilty
#  DispositionDate               | 2000-09-07
#  ConcludedBy                   | Guilty Plea
#  AmendedCharge                 | null
#  AmendedCodeSection            | null
#  AmendedChargeType             | null
#  JailPenitentiary              | null
#  ConcurrentConsecutive         | null
#  LifeDeath                     | null
#  SentenceTime                  | null
#  SentenceSuspended             | null
#  OperatorLicenseSuspensionTime | null
#  FineAmount                    | 100
#  Costs                         | 81
#  FinesCostPaid                 | t
#  ProgramType                   | null
#  ProbationType                 | null
#  ProbationTime                 | null
#  ProbationStarts               | null
#  CourtDMVSurrender             | null
#  DriverImprovementClinic       | null
#  DrivingRestrictions           | null
#  RestrictionEffectiveDate      | null
#  RestrictionEndDate            | null
#  VAAlcoholSafetyAction         | null
#  RestitutionPaid               | null
#  RestitutionAmount             | null
#  Military                      | null
#  TrafficFatality               | null
#  AppealedDate                  | null
#  person_id                     | 227220000000460
# -RECORD 8---------------------------------------------
#  HearingDate                   | 2000-09-07
#  HearingResult                 | Sent
#  HearingJury                   | null
#  HearingPlea                   | null
#  HearingType                   | Trial
#  HearingRoom                   | null
#  fips                          | 91
#  Filed                         | 2000-02-16
#  Commencedby                   | General District ...
#  Locality                      | COMMONWEALTH OF VA
#  Sex                           | Male
#  Race                          | White Caucasian (...
#  Address                       | BLUE GRASS, VA  2...
#  Charge                        | ATTEMPT TAKE DEER...
#  CodeSection                   | 29.1-523
#  ChargeType                    | Misdemeanor
#  Class                         | null
#  OffenseDate                   | 1999-11-19
#  ArrestDate                    | null
#  DispositionCode               | Guilty
#  DispositionDate               | 2000-09-07
#  ConcludedBy                   | Guilty Plea
#  AmendedCharge                 | null
#  AmendedCodeSection            | null
#  AmendedChargeType             | null
#  JailPenitentiary              | null
#  ConcurrentConsecutive         | null
#  LifeDeath                     | null
#  SentenceTime                  | null
#  SentenceSuspended             | null
#  OperatorLicenseSuspensionTime | null
#  FineAmount                    | 200
#  Costs                         | 33
#  FinesCostPaid                 | t
#  ProgramType                   | null
#  ProbationType                 | null
#  ProbationTime                 | null
#  ProbationStarts               | null
#  CourtDMVSurrender             | null
#  DriverImprovementClinic       | null
#  DrivingRestrictions           | null
#  RestrictionEffectiveDate      | null
#  RestrictionEndDate            | null
#  VAAlcoholSafetyAction         | null
#  RestitutionPaid               | null
#  RestitutionAmount             | null
#  Military                      | null
#  TrafficFatality               | null
#  AppealedDate                  | null
#  person_id                     | 227220000000460
# -RECORD 9---------------------------------------------
#  HearingDate                   | 2000-09-07
#  HearingResult                 | Sent
#  HearingJury                   | null
#  HearingPlea                   | null
#  HearingType                   | Trial
#  HearingRoom                   | null
#  fips                          | 91
#  Filed                         | 2000-02-16
#  Commencedby                   | General District ...
#  Locality                      | COMMONWEALTH OF VA
#  Sex                           | Male
#  Race                          | White Caucasian (...
#  Address                       | BLUE GRASS, VA  2...
#  Charge                        | ASSIST ATTEMPT DE...
#  CodeSection                   | 4VAC15-270-20
#  ChargeType                    | Misdemeanor
#  Class                         | null
#  OffenseDate                   | 1999-11-19
#  ArrestDate                    | null
#  DispositionCode               | Guilty
#  DispositionDate               | 2000-09-07
#  ConcludedBy                   | Guilty Plea
#  AmendedCharge                 | null
#  AmendedCodeSection            | null
#  AmendedChargeType             | null
#  JailPenitentiary              | null
#  ConcurrentConsecutive         | null
#  LifeDeath                     | null
#  SentenceTime                  | null
#  SentenceSuspended             | null
#  OperatorLicenseSuspensionTime | null
#  FineAmount                    | 50
#  Costs                         | 33
#  FinesCostPaid                 | t
#  ProgramType                   | null
#  ProbationType                 | null
#  ProbationTime                 | null
#  ProbationStarts               | null
#  CourtDMVSurrender             | null
#  DriverImprovementClinic       | null
#  DrivingRestrictions           | null
#  RestrictionEffectiveDate      | null
#  RestrictionEndDate            | null
#  VAAlcoholSafetyAction         | null
#  RestitutionPaid               | null
#  RestitutionAmount             | null
#  Military                      | null
#  TrafficFatality               | null
#  AppealedDate                  | null
#  person_id                     | 227220000000460
# -RECORD 10--------------------------------------------
#  HearingDate                   | 2000-09-07
#  HearingResult                 | Sent
#  HearingJury                   | null
#  HearingPlea                   | null
#  HearingType                   | Trial
#  HearingRoom                   | null
#  fips                          | 91
#  Filed                         | 2000-02-16
#  Commencedby                   | General District ...
#  Locality                      | COMMONWEALTH OF VA
#  Sex                           | Male
#  Race                          | White Caucasian (...
#  Address                       | BLUE GRASS, VA  2...
#  Charge                        | HUNT POSTED W/O W...
#  CodeSection                   | 18.2-134
#  ChargeType                    | Misdemeanor
#  Class                         | null
#  OffenseDate                   | 1999-11-19
#  ArrestDate                    | null
#  DispositionCode               | Guilty
#  DispositionDate               | 2000-09-07
#  ConcludedBy                   | Guilty Plea
#  AmendedCharge                 | null
#  AmendedCodeSection            | null
#  AmendedChargeType             | null
#  JailPenitentiary              | null
#  ConcurrentConsecutive         | null
#  LifeDeath                     | null
#  SentenceTime                  | null
#  SentenceSuspended             | null
#  OperatorLicenseSuspensionTime | null
#  FineAmount                    | 50
#  Costs                         | 53
#  FinesCostPaid                 | t
#  ProgramType                   | null
#  ProbationType                 | null
#  ProbationTime                 | null
#  ProbationStarts               | null
#  CourtDMVSurrender             | null
#  DriverImprovementClinic       | null
#  DrivingRestrictions           | null
#  RestrictionEffectiveDate      | null
#  RestrictionEndDate            | null
#  VAAlcoholSafetyAction         | null
#  RestitutionPaid               | null
#  RestitutionAmount             | null
#  Military                      | null
#  TrafficFatality               | null
#  AppealedDate                  | null
#  person_id                     | 227220000000460
# -RECORD 11--------------------------------------------
#  HearingDate                   | 2000-09-07
#  HearingResult                 | Nolle Prosequi
#  HearingJury                   | null
#  HearingPlea                   | null
#  HearingType                   | Trial
#  HearingRoom                   | null
#  fips                          | 91
#  Filed                         | 2000-02-16
#  Commencedby                   | General District ...
#  Locality                      | COMMONWEALTH OF VA
#  Sex                           | Male
#  Race                          | White Caucasian (...
#  Address                       | BLUE GRASS, VA  2...
#  Charge                        | ASSIST TO SHOOT F...
#  CodeSection                   | 29.1-521(6)
#  ChargeType                    | Misdemeanor
#  Class                         | null
#  OffenseDate                   | 1999-11-19
#  ArrestDate                    | null
#  DispositionCode               | Nolle Prosequi
#  DispositionDate               | 2000-09-07
#  ConcludedBy                   | Nolle Prosequi
#  AmendedCharge                 | null
#  AmendedCodeSection            | null
#  AmendedChargeType             | null
#  JailPenitentiary              | null
#  ConcurrentConsecutive         | null
#  LifeDeath                     | null
#  SentenceTime                  | null
#  SentenceSuspended             | null
#  OperatorLicenseSuspensionTime | null
#  FineAmount                    | null
#  Costs                         | null
#  FinesCostPaid                 | null
#  ProgramType                   | null
#  ProbationType                 | null
#  ProbationTime                 | null
#  ProbationStarts               | null
#  CourtDMVSurrender             | null
#  DriverImprovementClinic       | null
#  DrivingRestrictions           | null
#  RestrictionEffectiveDate      | null
#  RestrictionEndDate            | null
#  VAAlcoholSafetyAction         | null
#  RestitutionPaid               | null
#  RestitutionAmount             | null
#  Military                      | null
#  TrafficFatality               | null
#  AppealedDate                  | null
#  person_id                     | 227220000000460
# -RECORD 12--------------------------------------------
#  HearingDate                   | 2000-07-18
#  HearingResult                 | Dismissed
#  HearingJury                   | null
#  HearingPlea                   | null
#  HearingType                   | Motion - Other Po...
#  HearingRoom                   | null
#  fips                          | 91
#  Filed                         | 1997-12-02
#  Commencedby                   | Direct Indictment
#  Locality                      | COMMONWEALTH OF VA
#  Sex                           | Female
#  Race                          | White Caucasian (...
#  Address                       | WARM SPRINGS, VA ...
#  Charge                        | POSSESS COCAINE
#  CodeSection                   | 18.2-250
#  ChargeType                    | Felony
#  Class                         | null
#  OffenseDate                   | 1997-09-13
#  ArrestDate                    | 1997-12-18
#  DispositionCode               | Dismissed
#  DispositionDate               | 2000-07-18
#  ConcludedBy                   | Dismissal
#  AmendedCharge                 | null
#  AmendedCodeSection            | null
#  AmendedChargeType             | null
#  JailPenitentiary              | null
#  ConcurrentConsecutive         | null
#  LifeDeath                     | null
#  SentenceTime                  | null
#  SentenceSuspended             | null
#  OperatorLicenseSuspensionTime | null
#  FineAmount                    | null
#  Costs                         | null
#  FinesCostPaid                 | null
#  ProgramType                   | null
#  ProbationType                 | null
#  ProbationTime                 | null
#  ProbationStarts               | null
#  CourtDMVSurrender             | null
#  DriverImprovementClinic       | null
#  DrivingRestrictions           | null
#  RestrictionEffectiveDate      | null
#  RestrictionEndDate            | null
#  VAAlcoholSafetyAction         | null
#  RestitutionPaid               | null
#  RestitutionAmount             | null
#  Military                      | null
#  TrafficFatality               | null
#  AppealedDate                  | null
#  person_id                     | 101021000000426
# -RECORD 13--------------------------------------------
#  HearingDate                   | 2000-06-20
#  HearingResult                 | Granted
#  HearingJury                   | null
#  HearingPlea                   | null
#  HearingType                   | Motion - Other Po...
#  HearingRoom                   | null
#  fips                          | 91
#  Filed                         | 2000-03-13
#  Commencedby                   | Indictment
#  Locality                      | COMMONWEALTH OF VA
#  Sex                           | Male
#  Race                          | White Caucasian (...
#  Address                       | BLUE GRASS VA  24413
#  Charge                        | SODOMY WITH CHILD...
#  CodeSection                   | 18.2-67.1
#  ChargeType                    | Felony
#  Class                         | U
#  OffenseDate                   | 1999-06-23
#  ArrestDate                    | 1999-08-03
#  DispositionCode               | Guilty
#  DispositionDate               | 2000-04-20
#  ConcludedBy                   | Guilty Plea
#  AmendedCharge                 | null
#  AmendedCodeSection            | null
#  AmendedChargeType             | null
#  JailPenitentiary              | null
#  ConcurrentConsecutive         | null
#  LifeDeath                     | null
#  SentenceTime                  | null
#  SentenceSuspended             | null
#  OperatorLicenseSuspensionTime | null
#  FineAmount                    | null
#  Costs                         | 348
#  FinesCostPaid                 | t
#  ProgramType                   | null
#  ProbationType                 | null
#  ProbationTime                 | null
#  ProbationStarts               | null
#  CourtDMVSurrender             | null
#  DriverImprovementClinic       | null
#  DrivingRestrictions           | null
#  RestrictionEffectiveDate      | null
#  RestrictionEndDate            | null
#  VAAlcoholSafetyAction         | null
#  RestitutionPaid               | null
#  RestitutionAmount             | null
#  Military                      | null
#  TrafficFatality               | null
#  AppealedDate                  | null
#  person_id                     | 1070000000698
# -RECORD 14--------------------------------------------
#  HearingDate                   | 2000-06-20
#  HearingResult                 | Appeal Withdrawn
#  HearingJury                   | null
#  HearingPlea                   | null
#  HearingType                   | Term
#  HearingRoom                   | null
#  fips                          | 91
#  Filed                         | 2000-05-19
#  Commencedby                   | J&Dr Appeal
#  Locality                      | COMMONWEALTH OF VA
#  Sex                           | Male
#  Race                          | White Caucasian (...
#  Address                       | MONTEREY VA  24465
#  Charge                        | ASSAULT & BATTER
#  CodeSection                   | 18.2-57.2
#  ChargeType                    | Misdemeanor
#  Class                         | 1
#  OffenseDate                   | 2000-03-28
#  ArrestDate                    | null
#  DispositionCode               | Appeal Withdrawn
#  DispositionDate               | 2000-06-20
#  ConcludedBy                   | Withdrawn Prior T...
#  AmendedCharge                 | null
#  AmendedCodeSection            | null
#  AmendedChargeType             | null
#  JailPenitentiary              | Jail
#  ConcurrentConsecutive         | null
#  LifeDeath                     | null
#  SentenceTime                  | 30
#  SentenceSuspended             | 30
#  OperatorLicenseSuspensionTime | null
#  FineAmount                    | 100
#  Costs                         | 93
#  FinesCostPaid                 | t
#  ProgramType                   | null
#  ProbationType                 | null
#  ProbationTime                 | null
#  ProbationStarts               | null
#  CourtDMVSurrender             | null
#  DriverImprovementClinic       | null
#  DrivingRestrictions           | null
#  RestrictionEffectiveDate      | null
#  RestrictionEndDate            | null
#  VAAlcoholSafetyAction         | null
#  RestitutionPaid               | null
#  RestitutionAmount             | null
#  Military                      | null
#  TrafficFatality               | null
#  AppealedDate                  | null
#  person_id                     | 239010000000964
# -RECORD 15--------------------------------------------
#  HearingDate                   | 2000-06-01
#  HearingResult                 | Dismissed
#  HearingJury                   | null
#  HearingPlea                   | null
#  HearingType                   | Deferred Disposition
#  HearingRoom                   | null
#  fips                          | 91
#  Filed                         | 1998-06-22
#  Commencedby                   | Indictment
#  Locality                      | COMMONWEALTH OF VA
#  Sex                           | Male
#  Race                          | White Caucasian (...
#  Address                       | BLUE GRASS, VA  2...
#  Charge                        | POSSESS MARIJUANA
#  CodeSection                   | 18.2-248.1(A)2
#  ChargeType                    | Felony
#  Class                         | null
#  OffenseDate                   | 1998-03-21
#  ArrestDate                    | 1998-03-21
#  DispositionCode               | Dismissed
#  DispositionDate               | 2000-06-01
#  ConcludedBy                   | Dismissal
#  AmendedCharge                 | null
#  AmendedCodeSection            | null
#  AmendedChargeType             | null
#  JailPenitentiary              | null
#  ConcurrentConsecutive         | null
#  LifeDeath                     | null
#  SentenceTime                  | null
#  SentenceSuspended             | null
#  OperatorLicenseSuspensionTime | null
#  FineAmount                    | null
#  Costs                         | 342.5
#  FinesCostPaid                 | t
#  ProgramType                   | null
#  ProbationType                 | null
#  ProbationTime                 | null
#  ProbationStarts               | null
#  CourtDMVSurrender             | null
#  DriverImprovementClinic       | null
#  DrivingRestrictions           | null
#  RestrictionEffectiveDate      | null
#  RestrictionEndDate            | null
#  VAAlcoholSafetyAction         | null
#  RestitutionPaid               | null
#  RestitutionAmount             | null
#  Military                      | null
#  TrafficFatality               | null
#  AppealedDate                  | null
#  person_id                     | 142220000000116
# -RECORD 16--------------------------------------------
#  HearingDate                   | 2000-06-01
#  HearingResult                 | Dismissed
#  HearingJury                   | null
#  HearingPlea                   | null
#  HearingType                   | Trial
#  HearingRoom                   | null
#  fips                          | 91
#  Filed                         | 1999-12-10
#  Commencedby                   | Direct Indictment
#  Locality                      | COMMONWEALTH OF VA
#  Sex                           | Male
#  Race                          | Hispanic
#  Address                       | MONTEREY VA 24465
#  Charge                        | POSSESS FIREARM A...
#  CodeSection                   | 18.2-308.2
#  ChargeType                    | Felony
#  Class                         | 6
#  OffenseDate                   | null
#  ArrestDate                    | null
#  DispositionCode               | Not Guilty/Acquitted
#  DispositionDate               | 2000-06-01
#  ConcludedBy                   | Withdrawn Prior T...
#  AmendedCharge                 | null
#  AmendedCodeSection            | null
#  AmendedChargeType             | null
#  JailPenitentiary              | null
#  ConcurrentConsecutive         | null
#  LifeDeath                     | null
#  SentenceTime                  | null
#  SentenceSuspended             | null
#  OperatorLicenseSuspensionTime | null
#  FineAmount                    | null
#  Costs                         | null
#  FinesCostPaid                 | null
#  ProgramType                   | null
#  ProbationType                 | null
#  ProbationTime                 | null
#  ProbationStarts               | null
#  CourtDMVSurrender             | null
#  DriverImprovementClinic       | null
#  DrivingRestrictions           | null
#  RestrictionEffectiveDate      | null
#  RestrictionEndDate            | null
#  VAAlcoholSafetyAction         | null
#  RestitutionPaid               | null
#  RestitutionAmount             | null
#  Military                      | null
#  TrafficFatality               | null
#  AppealedDate                  | null
#  person_id                     | 239010000000964
# -RECORD 17--------------------------------------------
#  HearingDate                   | 2000-05-16
#  HearingResult                 | Nolle Prosequi
#  HearingJury                   | null
#  HearingPlea                   | null
#  HearingType                   | Plea
#  HearingRoom                   | null
#  fips                          | 91
#  Filed                         | 2000-05-16
#  Commencedby                   | Other
#  Locality                      | COMMONWEALTH OF VA
#  Sex                           | Male
#  Race                          | White Caucasian (...
#  Address                       | BLUE GRASS VA  24413
#  Charge                        | SEXUAL ABUSE CHIL...
#  CodeSection                   | 18.2-67.3(1)
#  ChargeType                    | Misdemeanor
#  Class                         | null
#  OffenseDate                   | 1999-06-23
#  ArrestDate                    | 1999-08-03
#  DispositionCode               | Nolle Prosequi
#  DispositionDate               | 2000-05-16
#  ConcludedBy                   | Nolle Prosequi
#  AmendedCharge                 | null
#  AmendedCodeSection            | null
#  AmendedChargeType             | null
#  JailPenitentiary              | null
#  ConcurrentConsecutive         | null
#  LifeDeath                     | null
#  SentenceTime                  | null
#  SentenceSuspended             | null
#  OperatorLicenseSuspensionTime | null
#  FineAmount                    | null
#  Costs                         | null
#  FinesCostPaid                 | null
#  ProgramType                   | null
#  ProbationType                 | null
#  ProbationTime                 | null
#  ProbationStarts               | null
#  CourtDMVSurrender             | null
#  DriverImprovementClinic       | null
#  DrivingRestrictions           | null
#  RestrictionEffectiveDate      | null
#  RestrictionEndDate            | null
#  VAAlcoholSafetyAction         | null
#  RestitutionPaid               | null
#  RestitutionAmount             | null
#  Military                      | null
#  TrafficFatality               | null
#  AppealedDate                  | null
#  person_id                     | 1070000000698
# -RECORD 18--------------------------------------------
#  HearingDate                   | 2000-04-20
#  HearingResult                 | Nolle Prosequi
#  HearingJury                   | null
#  HearingPlea                   | null
#  HearingType                   | Trial
#  HearingRoom                   | null
#  fips                          | 91
#  Filed                         | 2000-03-13
#  Commencedby                   | Indictment
#  Locality                      | COMMONWEALTH OF VA
#  Sex                           | Male
#  Race                          | White Caucasian (...
#  Address                       | BLUE GRASS VA  24413
#  Charge                        | SODOMY WITH CHILD...
#  CodeSection                   | 18.2-67.1
#  ChargeType                    | Felony
#  Class                         | U
#  OffenseDate                   | 1999-07-04
#  ArrestDate                    | 1999-08-03
#  DispositionCode               | Nolle Prosequi
#  DispositionDate               | 2000-04-20
#  ConcludedBy                   | Nolle Prosequi
#  AmendedCharge                 | null
#  AmendedCodeSection            | null
#  AmendedChargeType             | null
#  JailPenitentiary              | null
#  ConcurrentConsecutive         | null
#  LifeDeath                     | null
#  SentenceTime                  | null
#  SentenceSuspended             | null
#  OperatorLicenseSuspensionTime | null
#  FineAmount                    | null
#  Costs                         | null
#  FinesCostPaid                 | null
#  ProgramType                   | null
#  ProbationType                 | null
#  ProbationTime                 | null
#  ProbationStarts               | null
#  CourtDMVSurrender             | null
#  DriverImprovementClinic       | null
#  DrivingRestrictions           | null
#  RestrictionEffectiveDate      | null
#  RestrictionEndDate            | null
#  VAAlcoholSafetyAction         | null
#  RestitutionPaid               | null
#  RestitutionAmount             | null
#  Military                      | null
#  TrafficFatality               | null
#  AppealedDate                  | null
#  person_id                     | 1070000000698
# -RECORD 19--------------------------------------------
#  HearingDate                   | 2000-04-20
#  HearingResult                 | Sent
#  HearingJury                   | null
#  HearingPlea                   | null
#  HearingType                   | Under Advisement
#  HearingRoom                   | null
#  fips                          | 91
#  Filed                         | 1999-01-21
#  Commencedby                   | Indictment
#  Locality                      | COMMONWEALTH OF VA
#  Sex                           | Female
#  Race                          | White Caucasian (...
#  Address                       | MONTEREY, VA  24465
#  Charge                        | OBTAIN CONTROLLED...
#  CodeSection                   | 18.2-258.1
#  ChargeType                    | Felony
#  Class                         | null
#  OffenseDate                   | 1998-10-09
#  ArrestDate                    | 1998-11-18
#  DispositionCode               | Guilty
#  DispositionDate               | 2000-04-20
#  ConcludedBy                   | Guilty Plea
#  AmendedCharge                 | POSSESSION
#  AmendedCodeSection            | 18.2-250(C)
#  AmendedChargeType             | Misdemeanor
#  JailPenitentiary              | null
#  ConcurrentConsecutive         | null
#  LifeDeath                     | null
#  SentenceTime                  | null
#  SentenceSuspended             | null
#  OperatorLicenseSuspensionTime | null
#  FineAmount                    | null
#  Costs                         | 332
#  FinesCostPaid                 | null
#  ProgramType                   | null
#  ProbationType                 | null
#  ProbationTime                 | null
#  ProbationStarts               | null
#  CourtDMVSurrender             | null
#  DriverImprovementClinic       | null
#  DrivingRestrictions           | null
#  RestrictionEffectiveDate      | null
#  RestrictionEndDate            | null
#  VAAlcoholSafetyAction         | null
#  RestitutionPaid               | null
#  RestitutionAmount             | null
#  Military                      | null
#  TrafficFatality               | null
#  AppealedDate                  | null
#  person_id                     | 316071000000068
# only showing top 20 rows

# %%
from delta.tables import *
from pyspark.sql.functions import *

# set the path
deltaTable = DeltaTable.forPath(spark, "/tmp/delta-table-1")

# deltaTable.toDF().show()

type(deltaTable)
# Out:
# Out[18]: delta.tables.DeltaTable

# %%
# %sql 
-- selecting first 5 rows

SELECT * FROM delta.`/tmp/delta-table-1`
LIMIT 5;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>HearingDate</th><th>HearingResult</th><th>HearingJury</th><th>HearingPlea</th><th>HearingType</th><th>HearingRoom</th><th>fips</th><th>Filed</th><th>Commencedby</th><th>Locality</th><th>Sex</th><th>Race</th><th>Address</th><th>Charge</th><th>CodeSection</th><th>ChargeType</th><th>Class</th><th>OffenseDate</th><th>ArrestDate</th><th>DispositionCode</th><th>DispositionDate</th><th>ConcludedBy</th><th>AmendedCharge</th><th>AmendedCodeSection</th><th>AmendedChargeType</th><th>JailPenitentiary</th><th>ConcurrentConsecutive</th><th>LifeDeath</th><th>SentenceTime</th><th>SentenceSuspended</th><th>OperatorLicenseSuspensionTime</th><th>FineAmount</th><th>Costs</th><th>FinesCostPaid</th><th>ProgramType</th><th>ProbationType</th><th>ProbationTime</th><th>ProbationStarts</th><th>CourtDMVSurrender</th><th>DriverImprovementClinic</th><th>DrivingRestrictions</th><th>RestrictionEffectiveDate</th><th>RestrictionEndDate</th><th>VAAlcoholSafetyAction</th><th>RestitutionPaid</th><th>RestitutionAmount</th><th>Military</th><th>TrafficFatality</th><th>AppealedDate</th><th>person_id</th></tr></thead><tbody><tr><td>2000-12-19</td><td>Dismissed</td><td>null</td><td>null</td><td>Under Advisement</td><td>null</td><td>91</td><td>2000-02-16</td><td>General District Court Appeal</td><td>COMMONWEALTH OF VA</td><td>Male</td><td>White Caucasian (Non-Hispanic)</td><td>BLUE GRASS, VA  24413</td><td>ELUDE LAW ENFORCEMENT OFFICER</td><td>46.2-817</td><td>Misdemeanor</td><td>null</td><td>1999-11-19</td><td>null</td><td>Dismissed</td><td>2000-12-19</td><td>Dismissal</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>227220000000460</td></tr><tr><td>2000-09-19</td><td>Dismissed</td><td>null</td><td>null</td><td>Trial</td><td>null</td><td>91</td><td>2000-05-19</td><td>J&Dr Appeal</td><td>COMMONWEALTH OF VA</td><td>Male</td><td>White Caucasian (Non-Hispanic)</td><td>STAUNTON, VA  24401</td><td>OBSCENE PHONE CALL</td><td>18.2-427</td><td>Misdemeanor</td><td>1</td><td>2000-03-10</td><td>null</td><td>Not Guilty/Acquitted</td><td>2000-09-19</td><td>Dismissal</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>352110000000068</td></tr><tr><td>2000-09-07</td><td>Sent</td><td>null</td><td>null</td><td>Trial</td><td>null</td><td>91</td><td>2000-02-16</td><td>General District Court Appeal</td><td>COMMONWEALTH OF VA</td><td>Male</td><td>White Caucasian (Non-Hispanic)</td><td>BLUE GRASS, VA  24413</td><td>SHOOT FROM A ROAD</td><td>18.2-286</td><td>Misdemeanor</td><td>null</td><td>1999-11-19</td><td>null</td><td>Guilty</td><td>2000-09-07</td><td>Guilty Plea</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>300</td><td>81</td><td>t</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>216180000001247</td></tr><tr><td>2000-09-07</td><td>Nolle Prosequi</td><td>null</td><td>null</td><td>Trial</td><td>null</td><td>91</td><td>2000-02-16</td><td>General District Court Appeal</td><td>COMMONWEALTH OF VA</td><td>Male</td><td>White Caucasian (Non-Hispanic)</td><td>BLUE GRASS, VA  24413</td><td>SHOOT FROM A VEHICLE</td><td>29.1-521(6)</td><td>Misdemeano ...

# %%
# %sql
-- Showing the number of each ChargeType, descending by count

SELECT ChargeType, COUNT(*) as count
FROM delta.`/tmp/delta-table-1`
GROUP BY ChargeType
ORDER BY count DESC
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ChargeType</th><th>count</th></tr></thead><tbody><tr><td>Felony</td><td>92561</td></tr><tr><td>Misdemeanor</td><td>43921</td></tr><tr><td>Other (Animal Violations, Bond Appeals)</td><td>8</td></tr><tr><td>Infraction</td><td>5</td></tr><tr><td>null</td><td>3</td></tr><tr><td>Civil</td><td>1</td></tr></tbody></table></div>

# %%
deltaTable.toDF().groupby('ChargeType').count().orderBy(col('count'), ascending=False).show()
# Out:
# +--------------------+-----+
# |          ChargeType|count|
# +--------------------+-----+
# |              Felony|92561|
# |         Misdemeanor|43921|
# |Other (Animal Vio...|    8|
# |          Infraction|    5|
# |                null|    3|
# |               Civil|    1|
# +--------------------+-----+

# %%
# Creating a df with 2 rows, a subset of cols from Delta table, and a col not in the Delta table

deltaTable.update(
  set = { "fips" : expr("fips + 100")})

tbl1 = deltaTable.toDF().select('ChargeType', 'fips').limit(2)

# %%
tbl1.show()
# Out:
# +-----------+-----+
# | ChargeType| fips|
# +-----------+-----+
# |Misdemeanor|830.0|
# |Misdemeanor|830.0|
# +-----------+-----+

# %%
# Updating ChargeType: 'Infraction' to ChargeType: 'Minor Infraction' and updating Delta table
from pyspark.sql.functions import regexp_replace
df = deltaTable.toDF().withColumn('ChargeType', regexp_replace('ChargeType', 'Infraction', 'Minor Infraction'))
df.write.format("delta").mode("overwrite").save("/tmp/delta-table-1")

# %%
df.groupby('ChargeType').count().orderBy(col('count'), ascending=False).show()
# Out:
# +--------------------+-----+
# |          ChargeType|count|
# +--------------------+-----+
# |              Felony|92561|
# |         Misdemeanor|43921|
# |Other (Animal Vio...|    8|
# |Minor Minor Infra...|    5|
# |                null|    3|
# |               Civil|    1|
# +--------------------+-----+

# %%
# %sql

SELECT ChargeType, COUNT(*) as count
FROM delta.`/tmp/delta-table-1`
GROUP BY ChargeType
ORDER BY count DESC
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ChargeType</th><th>count</th></tr></thead><tbody><tr><td>Felony</td><td>92561</td></tr><tr><td>Misdemeanor</td><td>43921</td></tr><tr><td>Other (Animal Violations, Bond Appeals)</td><td>8</td></tr><tr><td>Minor Infraction</td><td>5</td></tr><tr><td>null</td><td>3</td></tr><tr><td>Civil</td><td>1</td></tr></tbody></table></div>

# %%
# Using time travel feature to load original version of delta table, where ChargeType is still 'Infraction'
df0 = spark.read.format("delta").option("versionAsOf", 0).load("/tmp/delta-table-1")
df0.select('HearingDate', 'HearingResult', 'ChargeType').filter(df0.ChargeType == 'Infraction').show()
# Out:
# +-----------+--------------------+----------+
# |HearingDate|       HearingResult|ChargeType|
# +-----------+--------------------+----------+
# | 2000-02-03|           Dismissed|Infraction|
# | 2000-06-15|                Sent|Infraction|
# | 2000-10-16|Resolved Order Pe...|Infraction|
# | 2000-01-12|            Resolved|Infraction|
# | 2000-05-10|                Sent|Infraction|
# +-----------+--------------------+----------+
